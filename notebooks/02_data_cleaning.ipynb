# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import glob
from pathlib import Path

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)

# ============================================================
# KONFIGURACJA
# ============================================================

LEAGUE = "premier_league"
# LEAGUE = "serie_a"
# LEAGUE = "la_liga"
# LEAGUE = "bundesliga"
# LEAGUE = "ligue_1"
# LEAGUE = "all_leagues"

RAW_BASE = Path("../data/raw")
OUT_DIR = Path(f"../data/processed/{LEAGUE}")
OUT_DIR.mkdir(parents=True, exist_ok=True)

# ============================================================
# MAPOWANIE LIG → FOLDER
# ============================================================

LEAGUE_DIRS = {
    "premier_league": RAW_BASE / "premier_league",
    "serie_a": RAW_BASE / "serie_a",
    "la_liga": RAW_BASE / "la_liga",
    "bundesliga": RAW_BASE / "bundesliga",
    "ligue_1": RAW_BASE / "ligue_1",
}

if LEAGUE == "all_leagues":
    files = []
    for d in LEAGUE_DIRS.values():
        files.extend(glob.glob(str(d / "*.csv")))
else:
    files = sorted(glob.glob(str(LEAGUE_DIRS[LEAGUE] / "*.csv")))

print(f"🔹 Liga: {LEAGUE}")
print(f"🔹 Liczba plików: {len(files)}")
# Out:
# 🔹 Liga: premier_league
# 🔹 Liczba plików: 9

# %%
def parse_date(df, date_col="Date"):
    """Konwersja kolumny daty do datetime.
    Pliki football-data.co.uk często mają format DD/MM/YY."""
    df[date_col] = pd.to_datetime(df[date_col], errors="coerce", dayfirst=True)
    return df

def add_season_from_date(df, date_col="Date"):
    """Dodaje kolumnę Season w formacie '2018/2019' na podstawie daty meczu."""
    y = df[date_col].dt.year
    m = df[date_col].dt.month

  
    y = pd.to_numeric(y, errors='coerce')

 
    season_start_year = np.where(m >= 7, y, y - 1)

  
    season_start_year = pd.Series(season_start_year).fillna(0).astype(int)


    df["Season"] = season_start_year.astype(str) + "/" + (season_start_year + 1).astype(str)

    return df


TEAM_ALIAS = {
    # === PREMIER LEAGUE ===
    "Man United": "Manchester United",
    "Man Utd": "Manchester United",
    "Man City": "Manchester City",
    "Spurs": "Tottenham",
    "Wolves": "Wolverhampton",
    "Newcastle Utd": "Newcastle",
    "Brighton and Hove Albion": "Brighton",
    "Brighton & Hove Albion": "Brighton",

    # === SERIE A ===
    "Inter": "Inter Milan",
    "Internazionale": "Inter Milan",
    "AC Milan": "Milan",
    "AS Roma": "Roma",
    "Hellas Verona": "Verona",

    # === LA LIGA ===
    "Ath Madrid": "Atletico Madrid",
    "Ath Bilbao": "Athletic Bilbao",
    "Betis": "Real Betis",
    "La Coruna": "Deportivo La Coruna",

    # === BUNDESLIGA ===
    "Bayern Munich": "Bayern Munich",
    "RB Leipzig": "RB Leipzig",
    "B M'gladbach": "Borussia Mönchengladbach",
    "B Dortmund": "Borussia Dortmund",

    # === LIGUE 1 ===
    "PSG": "Paris Saint-Germain",
    "Paris SG": "Paris Saint-Germain",
    "St Etienne": "Saint-Etienne",
    "Nimes": "Nîmes",
}
def normalize_team_names(df):
    for col in ["HomeTeam", "AwayTeam"]:
        df[col] = df[col].replace(TEAM_ALIAS)
    return df

def standardize_numeric(df, cols):
    """Wymuś typ float na wybranych kolumnach (kursy/statystyki)."""
    for c in cols:
        if c in df.columns:
            df[c] = pd.to_numeric(df[c], errors="coerce")
    return df

# %%
CORE_COLS = [
    'Div', 'Date', 'HomeTeam', 'AwayTeam', 
    'FTHG', 'FTAG', 'FTR',
    'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC',
    'HY', 'AY', 'HR', 'AR',
    'B365H', 'B365D', 'B365A',
    'PSH', 'PSD', 'PSA',
    'BbMxH', 'BbMxD', 'BbMxA',
    'BbAvH', 'BbAvD', 'BbAvA',
    'Bb1X2'
]

# %%
NUMERIC_COLS = [
    "FTHG","FTAG","HTHG","HTAG",
    "HS","AS","HST","AST","HF","AF","HC","AC","HY","AY","HR","AR",
    "B365H","B365D","B365A",
    "PSH","PSD","PSA",
    "BbMxH","BbMxD","BbMxA",
    "BbAvH","BbAvD","BbAvA",
    "Bb1X2"
]

dfs = []

for path in files:
    tmp = pd.read_csv(path)
    tmp = parse_date(tmp)
    tmp = normalize_team_names(tmp)
    tmp = standardize_numeric(tmp, NUMERIC_COLS)

    for c in CORE_COLS:
        if c not in tmp.columns:
            tmp[c] = np.nan

    tmp = tmp[CORE_COLS]
    tmp["SourceFile"] = Path(path).name
    tmp = add_season_from_date(tmp)

    if LEAGUE == "all_leagues":
        tmp["League"] = Path(path).stem.split("_")[0]

    dfs.append(tmp)

df_all = pd.concat(dfs, ignore_index=True)
df_all = df_all.sort_values("Date").reset_index(drop=True)

print("Połączone dane:", df_all.shape)

print(" Liczba plików (sezonów):", df_all.SourceFile.nunique())
# Out:
# C:\Users\tdroz\AppData\Local\Temp\ipykernel_8692\3705178861.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col], errors="coerce", dayfirst=True)
# C:\Users\tdroz\AppData\Local\Temp\ipykernel_8692\3705178861.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[date_col] = pd.to_datetime(df[date_col], errors="coerce", dayfirst=True)
# Połączone dane: (3421, 34)
#  Liczba plików (sezonów): 9

# %%
display(df_all.shape)
display(df_all.columns)

missing_raw = df_all.isnull().sum().sort_values(ascending=False)
missing_raw
# Out:
# (3421, 34)
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS',
#        'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR',
#        'B365H', 'B365D', 'B365A', 'PSH', 'PSD', 'PSA', 'BbMxH', 'BbMxD',
#        'BbMxA', 'BbAvH', 'BbAvD', 'BbAvA', 'Bb1X2', 'SourceFile', 'Season'],
#       dtype='object')
# Bb1X2         1521
# BbAvA         1521
# BbAvD         1521
# BbAvH         1521
# BbMxA         1521
# BbMxD         1521
# BbMxH         1521
# Div              1
# Date             1
# PSA              1
# PSD              1
# PSH              1
# B365A            1
# B365D            1
# B365H            1
# AR               1
# HR               1
# AY               1
# HY               1
# HomeTeam         1
# AwayTeam         1
# FTHG             1
# FTAG             1
# FTR              1
# HS               1
# AS               1
# HST              1
# AST              1
# HF               1
# AF               1
# HC               1
# ...

# %%
# ============================================================
# BRAKI DANYCH — LICZBA + PROCENT
# ============================================================

missing = df_all.isna().sum().sort_values(ascending=False)
missing_pct = (df_all.isna().mean() * 100).round(2)

missing_df = pd.DataFrame({
    "missing": missing,
    "missing_%": missing_pct
})

display(missing_df.head(30))


missing_df.to_csv(
    OUT_DIR / f"{LEAGUE}_missing_report.csv",
    index=True
)
# Out:
#           missing  missing_%
# AC              1       0.03
# AF              1       0.03
# AR              1       0.03
# AS              1       0.03
# AST             1       0.03
# AY              1       0.03
# AwayTeam        1       0.03
# B365A           1       0.03
# B365D           1       0.03
# B365H           1       0.03
# Bb1X2        1521      44.46
# BbAvA        1521      44.46
# BbAvD        1521      44.46
# BbAvH        1521      44.46
# BbMxA        1521      44.46
# BbMxD        1521      44.46
# BbMxH        1521      44.46
# Date            1       0.03
# Div             1       0.03
# FTAG            1       0.03
# FTHG            1       0.03
# FTR             1       0.03
# HC              1       0.03
# HF              1       0.03
# HR              1       0.03
# HS              1       0.03
# HST             1       0.03
# HY              1       0.03
# HomeTeam        1       0.03
# PSA             1       0.03

# %% [markdown]
# Widoczne braki danych dotyczą głównie kolumn bukmacherskich (BbAv*, BbMx*, Bb1X2), gdzie poziom braków sięga ok. 44% obserwacji. Jest to oczekiwane i naturalne, ponieważ w starszych sezonach te informacje nie były jeszcze zbierane lub publikowane.
#
# Pozostałe braki (na poziomie ~0.03%) dotyczą pojedynczych obserwacji w kluczowych kolumnach, takich jak Date, HomeTeam, AwayTeam, FTR czy podstawowe statystyki meczowe. Są to incydentalne przypadki, które nie mają istotnego wpływu na całościową analizę i mogą zostać bezpiecznie usunięte w dalszym etapie czyszczenia danych.
#
# Na obecnym etapie nie podejmowana jest decyzja o usuwaniu kolumn z dużym odsetkiem braków. Zostaną one zachowane, aby:
# - umożliwić późniejszą analizę ograniczoną do nowszych sezonów,
# - dać elastyczność w wyborze zestawu cech w kolejnych notebookach (feature engineering, modele),
# - zachować spójność struktury danych pomiędzy ligami.
#
# Ostateczna decyzja dotycząca wykorzystania lub odrzucenia tych zmiennych zostanie podjęta na etapie budowy modeli predykcyjnych, w zależności od wybranego horyzontu czasowego oraz dostępności danych w poszczególnych ligach.

# %% [markdown]
# # Porządkowanie: sortowanie, duplikaty, typy

# %%
df_all = df_all.sort_values("Date").reset_index(drop=True)


dup_count = df_all.duplicated(subset=["Date","HomeTeam","AwayTeam"]).sum()
print("Liczba potencjalnych duplikatów (Date, HomeTeam, AwayTeam):", dup_count)
df_all = df_all.drop_duplicates(subset=["Date","HomeTeam","AwayTeam"]).reset_index(drop=True)


if "FTR" in df_all.columns:
    df_all["FTR"] = df_all["FTR"].astype("category")
if "HTR" in df_all.columns:
    df_all["HTR"] = df_all["HTR"].astype("category")
# Out:
# Liczba potencjalnych duplikatów (Date, HomeTeam, AwayTeam): 0

# %%
before = df_all.shape[0]

df_all = df_all.dropna(
    subset=["Date", "HomeTeam", "AwayTeam"]
)

after = df_all.shape[0]

print(
    f"Usunięto {before - after} wierszy "
    "bez kluczowych informacji (Date/Home/Away)."
)
# Out:
# Usunięto 1 wierszy bez kluczowych informacji (Date/Home/Away).

# %% [markdown]
# # Sprawdzenie spójności nazw drużyn (po scaleniu sezonów)

# %%
home_teams = set(df_all["HomeTeam"].dropna().unique())
away_teams = set(df_all["AwayTeam"].dropna().unique())
teams_union = sorted(home_teams | away_teams)

print("Liczba unikalnych drużyn:", len(teams_union))
display(teams_union)
pd.Series(teams_union, name="Team").to_csv(
    OUT_DIR / f"{LEAGUE}_teams_list.csv",
    index=False
)
# Out:
# Liczba unikalnych drużyn: 34
# ['Arsenal',
#  'Aston Villa',
#  'Bournemouth',
#  'Brentford',
#  'Brighton',
#  'Burnley',
#  'Cardiff',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Fulham',
#  'Huddersfield',
#  'Hull',
#  'Leeds',
#  'Leicester',
#  'Liverpool',
#  'Luton',
#  'Manchester City',
#  'Manchester United',
#  'Middlesbrough',
#  'Newcastle',
#  'Norwich',
#  "Nott'm Forest",
#  'QPR',
#  'Sheffield United',
#  'Southampton',
#  'Stoke',
#  'Sunderland',
#  'Swansea',
#  'Tottenham',
#  'Watford',
#  'West Brom',
#  'West Ham',
#  'Wolverhampton']

# %%
CLEAN_COLS = [c for c in CORE_COLS if c in df_all.columns] + ["Season"]
if LEAGUE == "all_leagues":
    CLEAN_COLS.append("League")

df_clean = df_all[CLEAN_COLS].copy()
display(df_clean.head())
# Out:
#   Div       Date           HomeTeam        AwayTeam  FTHG  FTAG FTR    HS  \
# 0  E0 2014-08-16            Arsenal  Crystal Palace   2.0   1.0   H  14.0
# 1  E0 2014-08-16          Leicester         Everton   2.0   2.0   D  11.0
# 2  E0 2014-08-16  Manchester United         Swansea   1.0   2.0   A  14.0
# 3  E0 2014-08-16                QPR            Hull   0.0   1.0   A  19.0
# 4  E0 2014-08-16              Stoke     Aston Villa   0.0   1.0   A  12.0
#
#      AS  HST  AST    HF    AF   HC   AC   HY   AY   HR   AR  B365H  B365D  \
# 0   4.0  6.0  2.0  13.0  19.0  9.0  3.0  2.0  2.0  0.0  1.0   1.25    6.5
# 1  13.0  3.0  3.0  16.0  10.0  3.0  6.0  1.0  1.0  0.0  0.0   3.20    3.4
# 2   5.0  5.0  4.0  14.0  20.0  4.0  0.0  2.0  4.0  0.0  0.0   1.36    5.0
# 3  11.0  6.0  4.0  10.0  10.0  8.0  9.0  1.0  2.0  0.0  0.0   2.50    3.3
# 4   7.0  2.0  2.0  14.0   9.0  2.0  8.0  0.0  3.0  0.0  0.0   1.95    3.5
#
# ...

# %% [markdown]
# # Zapis zestawu danych do /data/processed/

# %%
out_file = f"{LEAGUE}_clean.csv"
out_path = OUT_DIR / out_file

df_clean.to_csv(out_path, index=False)

print("Zapisano plik:", out_path)
print("Wymiary:", df_clean.shape)
# Out:
# Zapisano plik: ..\data\processed\premier_league\premier_league_clean.csv
# Wymiary: (3420, 33)

# %%
report = {
    "league": LEAGUE,
    "rows": int(df_clean.shape[0]),
    "cols": int(df_clean.shape[1]),
    "seasons": sorted(df_clean["Season"].unique().tolist()),
    "teams": len(teams_union),
    "files_used": int(df_all["SourceFile"].nunique())
}

report_df = pd.DataFrame.from_dict(report, orient="index", columns=["value"])
display(report_df)

report_df.to_csv(
    OUT_DIR / f"{LEAGUE}_cleaning_report.csv"
)
# Out:
#                                                         value
# league                                         premier_league
# rows                                                     3420
# cols                                                       33
# seasons     [2014/2015, 2015/2016, 2016/2017, 2017/2018, 2...
# teams                                                      34
# files_used                                                  9

# %% [markdown]
# ## Podsumowanie etapu czyszczenia danych
#
# - Połączono dane meczowe dla wybranej ligi (lub wszystkich lig) z wielu sezonów, obejmujących zarówno starsze, jak i nowsze rozgrywki.
# - Zbiór danych zawiera kompletne informacje meczowe (daty, drużyny, wyniki, statystyki boiskowe oraz kursy bukmacherskie tam, gdzie były dostępne).
# - Ujednolicono format kolumny `Date` oraz nazwy drużyn (normalizacja aliasów), co pozwala na spójne łączenie danych między sezonami.
# - Usunięto potencjalne duplikaty meczów na podstawie kombinacji: data, drużyna gospodarzy i drużyna gości.
# - Zidentyfikowano braki danych, które występują głównie w starszych sezonach i dotyczą przede wszystkim wybranych kursów bukmacherskich (np. `BbAv*`, `BbMx*`).
# - Braki w kluczowych kolumnach meczowych (wyniki, drużyny, daty) są marginalne i zostały usunięte; pozostałe zmienne pozostawiono bez imputacji na tym etapie.
# - Ostateczny, oczyszczony zbiór danych zapisano w katalogu `/data/processed/` w formacie CSV, z zachowaniem informacji o sezonie oraz (opcjonalnie) lidze.
#
# Na tym etapie **nie podejmowano decyzji o imputacji brakujących kursów bukmacherskich** — zostanie to rozważone na etapie *feature engineeringu* w zależności od wybranej specyfikacji modelu.
#
# Dane są gotowe do kolejnego etapu analizy:
# **inżynierii cech, budowy modeli predykcyjnych oraz porównań między sezonami i ligami.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,4))
sns.countplot(
    x="FTR",
    data=df_clean,
    order=df_clean["FTR"].value_counts().index
)
plt.title("Rozkład wyników meczów (H/D/A)")
plt.xlabel("Wynik")
plt.ylabel("Liczba meczów")

plt.savefig(
    OUT_DIR / f"{LEAGUE}_ftr_distribution.png",
    dpi=150,
    bbox_inches="tight"
)
plt.show()
plt.close()

df_clean["FTR"].value_counts(normalize=True) * 100
# Out:
# FTR
# H    44.912
# A    31.871
# D    23.216
# Name: proportion, dtype: float64

# %%
df_clean["TotalGoals"] = df_clean["FTHG"] + df_clean["FTAG"]
df_clean["Month"] = df_clean["Date"].dt.month

monthly_goals = df_clean.groupby("Month")["TotalGoals"].mean()

plt.figure(figsize=(10,5))
sns.lineplot(
    x=monthly_goals.index,
    y=monthly_goals.values,
    marker="o",
    linewidth=2
)
plt.title("Średnia liczba goli w miesiącach sezonu")
plt.xlabel("Miesiąc")
plt.ylabel("Średnia liczba goli")
plt.grid(True)

plt.savefig(
    OUT_DIR / f"{LEAGUE}_monthly_goals.png",
    dpi=150,
    bbox_inches="tight"
)
plt.show()
plt.close()

# %%
df_plot = df_clean.dropna(
    subset=["FTR", "HomeTeam", "AwayTeam"]
)

pivot = pd.crosstab(
    df_plot["HomeTeam"],
    df_plot["AwayTeam"],
    values=(df_plot["FTR"] == "H").astype(int),
    aggfunc="mean"
)

plt.figure(figsize=(14,12))
sns.heatmap(
    pivot,
    cmap="Greens",
    cbar_kws={"label": "P(Home Win)"},
    square=True,
    annot = True,
    fmt=".2f",               
    annot_kws={"size": 7},   
    mask=pivot.isna() 
)
plt.title("Procent zwycięstw gospodarzy")
plt.tight_layout()

plt.savefig(
    OUT_DIR / f"{LEAGUE}_home_win_heatmap.png",
    dpi=150,
    bbox_inches="tight"
)
plt.show()
plt.close()
