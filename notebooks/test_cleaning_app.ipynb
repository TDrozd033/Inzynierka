# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent  
sys.path.append(str(PROJECT_ROOT))

# %%
from pathlib import Path
import os

p = Path("data_app/raw")
print("data_app/raw istnieje:", p.exists())
print("Zawartość:", list(p.iterdir()) if p.exists() else "BRAK")
# Out:
# data_app/raw istnieje: False
# Zawartość: BRAK

# %%
p2 = Path("data/raw_app/raw")
print("data/raw_app/raw istnieje:", p2.exists())
print("Zawartość:", list(p2.iterdir()) if p2.exists() else "BRAK")
# Out:
# data/raw_app/raw istnieje: False
# Zawartość: BRAK

# %%
from pathlib import Path
import sys


PROJECT_ROOT = Path.cwd().parents[0]


sys.path.append(str(PROJECT_ROOT))


DATA_DIR = PROJECT_ROOT / "data_app" / "raw"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("DATA_DIR istnieje:", DATA_DIR.exists())
print("Zawartość DATA_DIR:", list(DATA_DIR.iterdir()))
# Out:
# PROJECT_ROOT: c:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca
# DATA_DIR istnieje: True
# Zawartość DATA_DIR: [WindowsPath('c:/Users/tdroz/OneDrive/Pulpit/Praca_Inzynierska/Praca/data_app/raw/bundesliga'), WindowsPath('c:/Users/tdroz/OneDrive/Pulpit/Praca_Inzynierska/Praca/data_app/raw/la_liga'), WindowsPath('c:/Users/tdroz/OneDrive/Pulpit/Praca_Inzynierska/Praca/data_app/raw/ligue_1'), WindowsPath('c:/Users/tdroz/OneDrive/Pulpit/Praca_Inzynierska/Praca/data_app/raw/premier_league'), WindowsPath('c:/Users/tdroz/OneDrive/Pulpit/Praca_Inzynierska/Praca/data_app/raw/serie_a')]

# %%
from src.cleaning_app import load_all_leagues

df = load_all_leagues(DATA_DIR)

print("Shape:", df.shape)
print("\nLigi:")
print(df["League"].value_counts())

df.head()
# Out:
# ▶ Ładowanie ligi: premier_league
# C:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca\src\cleaning_app.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)
# C:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca\src\cleaning_app.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)
# ▶ Ładowanie ligi: serie_a
# C:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca\src\cleaning_app.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %%
# %cd ..
# Out:
# c:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca
# C:\Users\tdroz\AppData\Roaming\Python\Python311\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca

# %%
from src.cleaning_app import load_all_leagues
from pathlib import Path

df = load_all_leagues(Path("data_app/raw"))

out_dir = Path("data_app/processed/all_leagues")
out_dir.mkdir(parents=True, exist_ok=True)

out_path = out_dir / "all_leagues_clean.csv"
df.to_csv(out_path, index=False)

print("Zapisano:", out_path)
print(df.shape)
# Out:
# ▶ Ładowanie ligi: premier_league
# C:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca\src\cleaning_app.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)
# C:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca\src\cleaning_app.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce", dayfirst=True)
# ▶ Ładowanie ligi: serie_a
# C:\Users\tdroz\OneDrive\Pulpit\Praca_Inzynierska\Praca\src\cleaning_app.py:74: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
# ...

# %% [markdown]
# # Test FE_app

# %%
import pandas as pd

df = pd.read_csv("data_app/processed/all_leagues/all_leagues_features.csv")

print(df.shape)
print(df.columns[:20])
print(df.columns[-20:])
# Out:
# (20483, 106)
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HS',
#        'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR',
#        'B365H'],
#       dtype='object')
# Index(['Home_AvgPts_season', 'Home_AvgGD_season', 'Away_AvgPts_season',
#        'Away_AvgGD_season', 'SeasonStrength_PtsDiff', 'SeasonStrength_GDDiff',
#        'Home_AttDefRatio_last5', 'Home_GoalsShare_last5',
#        'Away_AttDefRatio_last5', 'Away_GoalsShare_last5',
#        'FormDiff_AttDefRatio_last5', 'FormDiff_GoalsShare_last5',
#        'Home_RecentFormIdx', 'Away_RecentFormIdx', 'FormDiff_RecentFormIdx',
#        'Market_ImpliedDiff_b365', 'Market_ImpliedDiff_ps', 'Market_BigHomeFav',
#        'Market_BigAwayFav', 'Market_BalancedMatch'],
#       dtype='object')

# %%
leak_cols = [c for c in df.columns if any(x in c for x in ["FTHG","FTAG","GoalDiff","TotalGoals"])]
leak_cols
# Out:
# ['FTHG', 'FTAG', 'GoalDiff', 'TotalGoals']
